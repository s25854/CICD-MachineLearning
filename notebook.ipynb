# %%
import pandas as pd

drug_df = pd.read_csv("Data/drug200.csv")
drug_df = drug_df.sample(frac=1)
drug_df.head(3)
# Out:
#      Age Sex    BP Cholesterol  Na_to_K   Drug
# 171   45   M   LOW      NORMAL   10.017  drugX
# 149   22   M   LOW        HIGH    8.151  drugC
# 46    37   F  HIGH        HIGH   13.091  drugA

# %%
from sklearn.model_selection import train_test_split

X = drug_df.drop("Drug", axis=1).values
y = drug_df.Drug.values

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=125
)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OrdinalEncoder, StandardScaler

cat_col = [1,2,3]
num_col = [0,4]

transform = ColumnTransformer(
    [
        ("encoder", OrdinalEncoder(), cat_col),
        ("num_imputer", SimpleImputer(strategy="median"), num_col),
        ("num_scaler", StandardScaler(), num_col),
    ]
)
pipe = Pipeline(
    steps=[
        ("preprocessing", transform),
        ("model", RandomForestClassifier(n_estimators=100, random_state=125)),
    ]
)
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('encoder', OrdinalEncoder(),
#                                                   [1, 2, 3]),
#                                                  ('num_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   [0, 4]),
#                                                  ('num_scaler',
#                                                   StandardScaler(), [0, 4])])),
#                 ('model', RandomForestClassifier(random_state=125))])

# %%
from sklearn.metrics import accuracy_score, f1_score

predictions = pipe.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
f1 = f1_score(y_test, predictions, average="macro")

print("Accuracy:", str(round(accuracy, 2) * 100) + "%", "F1:", round(f1, 2))
# Out:
# Accuracy: 90.0% F1: 0.85

# %%
with open("Results/metrics.txt", "w") as outfile:
    outfile.write(f"\nAccuracy = {accuracy}, F1 Score = {f1}.")

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

cm = confusion_matrix(y_test, predictions, labels=pipe.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipe.classes_)
disp.plot()
plt.savefig("Results/model_results.png", dpi=120)

# %%
import skops.io as sio

sio.dump(pipe, "Model/drug_pipeline.skops")

# %%
sio.load("Model/drug_pipeline.skops", trusted=True)
# Out:
# ---------------------------------------------------------------------------
# UntrustedTypesFoundException              Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sio.load("Model/drug_pipeline.skops")
#
# File ~\Desktop\CICD\CICD-MachineLearning\venv\Lib\site-packages\skops\io\_persist.py:151, in load(file, trusted)
#     149     load_context = LoadContext(src=input_zip, protocol=schema["protocol"])
#     150     tree = get_tree(schema, load_context, trusted=trusted)
# --> 151     audit_tree(tree)
#     152     instance = tree.construct()
#     154 return instance
#
# File ~\Desktop\CICD\CICD-MachineLearning\venv\Lib\site-packages\skops\io\_audit.py:59, in audit_tree(tree)
#      57 unsafe = tree.get_unsafe_set()
#      58 if unsafe:
# ---> 59     raise UntrustedTypesFoundException(unsafe)
#
# UntrustedTypesFoundException: Untrusted types found in the file: ['numpy.dtype'].
